# %% [markdown]
# # Statistical Profiling

# %%
import polars as pl
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pl.read_parquet('../data/processed/ip_features.parquet').to_pandas()

# %%
df.describe(include='all')
# Out:
#                ip  total_requests  unique_invoice_ids  successful_requests  \
# count        5726     5726.000000         5726.000000          5726.000000
# unique       5726             NaN                 NaN                  NaN
# top     27.0.4.48             NaN                 NaN                  NaN
# freq            1             NaN                 NaN                  NaN
# mean          NaN      782.154907          707.656829           523.071952
# min           NaN      494.000000          465.000000           315.000000
# 25%           NaN      620.250000          584.000000           418.000000
# 50%           NaN      788.000000          715.000000           517.000000
# 75%           NaN      852.000000          776.000000           569.000000
# max           NaN    12453.000000         6481.000000          9841.000000
# std           NaN      404.188134          226.339540           309.797049
#
#         failed_requests  success_rate   error_rate  unique_tokens  \
# count       5726.000000   5726.000000  5726.000000    5726.000000
# unique              NaN           NaN          NaN            NaN
# top                 NaN           NaN          NaN            NaN
# freq                NaN           NaN          NaN            NaN
# mean         259.082955      0.666957     0.333043      30.976423
# min          140.000000      0.600000     0.207591       4.000000
# 25%          210.000000      0.655120     0.321496      31.000000
# 50%          256.000000      0.667028     0.332972      31.000000
# 75%          286.000000      0.678504     0.344880      31.000000
# max         2681.000000      0.792409     0.400000      31.000000
# std           99.219022      0.018213     0.018213       0.797575
#
#         unique_user_agents                  first_seen  \
# count          5726.000000                        5726
# unique                 NaN                         NaN
# top                    NaN                         NaN
# freq                   NaN                         NaN
# mean              4.999127  2020-10-27 12:18:42.930492
# min               3.000000         2020-10-01 00:00:00
# 25%               5.000000         2020-10-01 00:53:00
# 50%               5.000000         2020-11-01 00:11:00
# 75%               5.000000         2020-12-01 00:15:00
# max               6.000000         2020-12-01 09:01:00
# std               0.066076                         NaN
#
#                          last_seen  active_minutes  requests_per_minute  \
# count                         5726     5726.000000          5726.000000
# unique                         NaN             NaN                  NaN
# top                            NaN             NaN                  NaN
# freq                           NaN             NaN                  NaN
# mean    2020-12-04 01:35:44.628012    54077.028292             0.015170
# min            2020-10-31 15:58:00    42692.000000             0.008342
# 25%            2020-11-30 15:02:00    44261.000000             0.012551
# 50%            2020-11-30 23:14:00    44523.000000             0.015066
# 75%            2020-12-31 22:06:00    44619.000000             0.019149
# max            2020-12-31 23:59:00   132474.000000             0.094022
# std                            NaN    18433.860425             0.004580
#
#         min_invoice_id  max_invoice_id  invoice_span  sequential_access_ratio
# count     5.726000e+03    5.726000e+03  5.726000e+03              5726.000000
# unique             NaN             NaN           NaN                      NaN
# top                NaN             NaN           NaN                      NaN
# freq               NaN             NaN           NaN                      NaN
# mean      1.188220e+08    2.299340e+08  1.111120e+08                 0.156135
# min       1.188220e+08    2.299339e+08  1.111119e+08                 0.066667
# 25%       1.188220e+08    2.299340e+08  1.111120e+08                 0.119098
# 50%       1.188220e+08    2.299340e+08  1.111120e+08                 0.140450
# 75%       1.188220e+08    2.299340e+08  1.111120e+08                 0.159151
# max       1.188221e+08    2.299340e+08  1.111120e+08                 0.662809
# std       6.918493e+00    7.168075e+00  1.022188e+01                 0.073035

# %%
numeric = df.select_dtypes(include='number')
numeric.hist(figsize=(14,10))
plt.tight_layout()
