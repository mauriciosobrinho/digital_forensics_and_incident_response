# %% [markdown]
# # Executive Dashboard

# %%
import polars as pl
import matplotlib.pyplot as plt

# %%
df = pl.read_parquet('../data/processed/ip_features.parquet').to_pandas()

# %%
top=df.sort_values('total_requests',ascending=False).head(20)

# %%
top.plot.bar(x='ip',y='total_requests',figsize=(14,6))
plt.tight_layout()
