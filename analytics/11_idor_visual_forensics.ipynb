# %% [markdown]
# # IDOR Visual Forensics

# %%
import polars as pl
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pl.read_parquet('../data/processed/ip_features.parquet').to_pandas()

# %%
top=df.sort_values('sequential_access_ratio',ascending=False).head(50)

# %%
sns.scatterplot(data=top,x='unique_invoice_ids',y='sequential_access_ratio')
plt.show()
