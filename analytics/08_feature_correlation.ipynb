# %% [markdown]
# # Feature Correlation

# %%
import polars as pl
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Running cells with '.venv-1 (3.12.0) (Python 3.12.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/mlsob/Developer/idor-response-platform/.venv-1/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
df = pl.read_parquet('../data/processed/ip_features.parquet').to_pandas()

# %%
corr = df.select_dtypes(include='number').corr()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(corr, annot=False)
plt.show()
